# %%
# Import library
import pandas as pd
import seaborn as sb

# %%
# Read the dataset
data = pd.read_csv('USA_Housing.csv')

# %%
data
# Out:
#       Avg. Area Income  ...                                            Address
# 0          79545.45857  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1          79248.64245  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2          61287.06718  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3          63345.24005  ...                          USS Barnett\nFPO AP 44820
# 4          59982.19723  ...                         USNS Raymond\nFPO AE 09386
# ...                ...  ...                                                ...
# 4995       60567.94414  ...                   USNS Williams\nFPO AP 30153-7653
# 4996       78491.27543  ...              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997       63390.68689  ...  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998       68001.33124  ...                          USS Wallace\nFPO AE 73316
# 4999       65510.58180  ...  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  ...  Area Population         Price
# count       5000.000000          5000.000000  ...      5000.000000  5.000000e+03
# mean       68583.108984             5.977222  ...     36163.516039  1.232073e+06
# std        10657.991214             0.991456  ...      9925.650114  3.531176e+05
# min        17796.631190             2.644304  ...       172.610686  1.593866e+04
# 25%        61480.562390             5.322283  ...     29403.928700  9.975771e+05
# 50%        68804.286405             5.970429  ...     36199.406690  1.232669e+06
# 75%        75783.338665             6.650808  ...     42861.290770  1.471210e+06
# max       107701.748400             9.519088  ...     69621.713380  2.469066e+06
#
# [8 rows x 6 columns]

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(data, c='g', alpha=0.7 ,figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd4702ec110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd4702c29d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd4702d2b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd47028a710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd470240d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd470202450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd4701b7b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd47017a150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd47017a190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd47012f910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd4700a8550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd4700ddbd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd470097dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd470058390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd47000f910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46ffc3e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46ff85450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46ff3e9d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fef2f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46feb4510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fe69a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fea0fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fe625d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fe1de90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fde1190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fd966d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fd4ac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fd0f210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fcc3790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fc77d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fc3a2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fbf0850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fba8dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fb69390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fb9e910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd46fb54e90>]],
#       dtype=object)

# %%
sb.heatmap(data.corr())

# %%
data = data.dropna()

# %%
data
# Out:
#       Avg. Area Income  ...                                            Address
# 0          79545.45857  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1          79248.64245  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2          61287.06718  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3          63345.24005  ...                          USS Barnett\nFPO AP 44820
# 4          59982.19723  ...                         USNS Raymond\nFPO AE 09386
# ...                ...  ...                                                ...
# 4995       60567.94414  ...                   USNS Williams\nFPO AP 30153-7653
# 4996       78491.27543  ...              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997       63390.68689  ...  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998       68001.33124  ...                          USS Wallace\nFPO AE 73316
# 4999       65510.58180  ...  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
# Select price as target variable
y = data.iloc[:, -2].values

# %%
# Select the fatures
x = data.iloc[:, [0,1,2,3,4]].values

# %%
# Library to Split the train test set
from sklearn.model_selection import train_test_split as tts

# %%
# Split the train test
x_train, x_test, y_train, y_test = tts(x, y, test_size=0.2, random_state=4)

# %%
# Output is continuous data
# Choose linear regression model
from sklearn.linear_model import LinearRegression

# %%
# Create the model
linreg = LinearRegression()

# %%
# Fit the model
linreg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predict the accuracy
linreg.score(x_test, y_test)
# Out:
# 0.9221179988588107
